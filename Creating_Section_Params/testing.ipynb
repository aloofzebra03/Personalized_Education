# %%
import pandas as pd
df = pd.read_csv('output/ground_truth_sections_params.csv')

# %%
df.to_json(index=False, orient='records')
# Out:
# '[{"conceptual_clarity_level":3,"retention_strength":65.0,"family_responsibilities_hrs":2,"metacognitive_skill_level":3,"ongoing_concept":"Uniform Linear Motion","error_pattern":"calculation","input_method_preference":"typing","content_type_preference":"[\'video\', \'practice_tests\']","next_section":"Intuition","difficulty":3,"board_exam_importance":3,"olympiad_importance":4,"avg_study_time_min":3,"interest_evoking":4,"curiosity_evoking":4,"critical_reasoning_needed":3,"inquiry_learning_scope":4,"example_availability":4},{"conceptual_clarity_level":2,"retention_strength":45.0,"family_responsibilities_hrs":4,"metacognitive_skill_level":1,"ongoing_concept":"Water Clock","error_pattern":"conceptual","input_method_preference":"voice","content_type_preference":"[\'text\', \'simulation\']","next_section":"Explanation (with analogies)","difficulty":2,"board_exam_importance":3,"olympiad_importance":2,"avg_study_time_min":2,"interest_evoking":4,"curiosity_evoking":4,"critical_reasoning_needed":2,"inquiry_learning_scope":3,"example_availability":4},{"conceptual_clarity_level":4,"retention_strength":80.0,"family_responsibilities_hrs":1,"metacognitive_skill_level":4,"ongoing_concept":"Non-uniform Linear Motion","error_pattern":"careless","input_method_preference":"typing","content_type_preference":"[\'video\', \'simulation\']","next_section":"Critical Thinking","difficulty":4,"board_exam_importance":4,"olympiad_importance":3,"avg_study_time_min":3,"interest_evoking":4,"curiosity_evoking":4,"critical_reasoning_needed":5,"inquiry_learning_scope":4,"example_availability":3},{"conceptual_clarity_level":2,"retention_strength":55.0,"family_responsibilities_hrs":3,"metacognitive_skill_level":2,"ongoing_concept":"Hourglass","error_pattern":"calculation","input_method_preference":"writing","content_type_preference":"[\'text\', \'video\']","next_section":"Working","difficulty":2,"board_exam_importance":3,"olympiad_importance":2,"avg_study_time_min":3,"interest_evoking":3,"curiosity_evoking":2,"critical_reasoning_needed":3,"inquiry_learning_scope":2,"example_availability":4},{"conceptual_clarity_level":5,"retention_strength":90.0,"family_responsibilities_hrs":0,"metacognitive_skill_level":5,"ongoing_concept":"Non-uniform Linear Motion","error_pattern":"careless","input_method_preference":"typing","content_type_preference":"[\'simulation\', \'gamified\']","next_section":"Critical Thinking","difficulty":5,"board_exam_importance":4,"olympiad_importance":5,"avg_study_time_min":3,"interest_evoking":5,"curiosity_evoking":5,"critical_reasoning_needed":5,"inquiry_learning_scope":4,"example_availability":4},{"conceptual_clarity_level":3,"retention_strength":70.0,"family_responsibilities_hrs":2,"metacognitive_skill_level":3,"ongoing_concept":"Uniform Linear Motion","error_pattern":"conceptual","input_method_preference":"typing","content_type_preference":"[\'video\', \'practice_tests\']","next_section":"Intuition","difficulty":3,"board_exam_importance":3,"olympiad_importance":4,"avg_study_time_min":3,"interest_evoking":4,"curiosity_evoking":4,"critical_reasoning_needed":3,"inquiry_learning_scope":4,"example_availability":4},{"conceptual_clarity_level":1,"retention_strength":30.0,"family_responsibilities_hrs":5,"metacognitive_skill_level":1,"ongoing_concept":"Water Clock","error_pattern":"conceptual","input_method_preference":"voice","content_type_preference":"[\'text\']","next_section":"Concept Definition","difficulty":1,"board_exam_importance":3,"olympiad_importance":1,"avg_study_time_min":2,"interest_evoking":2,"curiosity_evoking":3,"critical_reasoning_needed":1,"inquiry_learning_scope":2,"example_availability":3},{"conceptual_clarity_level":4,"retention_strength":75.0,"family_responsibilities_hrs":1,"metacognitive_skill_level":4,"ongoing_concept":"Non-uniform Linear Motion","error_pattern":"careless","input_method_preference":"typing","content_type_preference":"[\'video\', \'simulation\']","next_section":"Intuition","difficulty":4,"board_exam_importance":3 ...

# %%
df['next_section'].value_counts()
# Out:
# next_section
# Intuition                        650
# Explanation (with analogies)     642
# Concept Definition               142
# Working                           33
# Critical Thinking                 32
# Details (facts, sub-concepts)      1
# Name: count, dtype: int64

# %%
df_temp0 = pd.read_csv('output/ground_truth_sections_params_temp0.csv')
df_temp0['next_section'].value_counts()
# Out:
# next_section
# Intuition                       658
# Explanation (with analogies)    638
# Concept Definition              146
# Critical Thinking                32
# Working                          26
# Name: count, dtype: int64
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
df.columns
# Out:
# Index(['conceptual_clarity_level', 'attention_span_category',
#        'retention_strength', 'problem_solving_speed_sec', 'error_pattern',
#        'growth_slope', 'response_to_feedback', 'revisions_per_week',
#        'days_between_revisions', 'method_of_revision',
#        'question_asking_nature', 'self_assessment_accuracy',
#        'exploration_tendency', 'teacher_relationship_quality',
#        'peer_learning_behavior', 'communication_clarity',
#        'discussion_engagement', 'test_anxiety_level',
#        'resilience_after_failure', 'motivation_intrinsic_vs_extrinsic',
#        'achievement_orientation', 'emotional_self_awareness',
#        'device_access_type', 'preferred_edtech_apps',
#        'digital_distraction_level', 'input_method_preference',
#        'highest_academic_level', 'study_space_quality',
#        'academic_pressure_at_home', 'family_responsibilities_hrs',
#        'support_system_strength', 'content_type_preference',
#        'knowledge_graph_nodes_covered', 'metacognitive_skill_level',
#        'ongoing_concept', 'next_section', 'difficulty',
#        'board_exam_importance', 'olympiad_importance', 'avg_study_time_min',
#        'interest_evoking', 'curiosity_evoking', 'critical_reasoning_needed',
#        'inquiry_learning_scope', 'example_availability'],
#       dtype='object')

# %%
df[df['next_section']=='Explanation (with analogies)'].duplicated(subset=['next_section','difficulty',
       'board_exam_importance', 'olympiad_importance', 'avg_study_time_min',
       'interest_evoking', 'curiosity_evoking', 'critical_reasoning_needed',
       'inquiry_learning_scope', 'example_availability']).sum()
# Out:
# np.int64(1356)

# %%
df[df['next_section']=='Real-Life Application'].duplicated(subset=['next_section','difficulty',
       'board_exam_importance', 'olympiad_importance', 'avg_study_time_min',
       'interest_evoking', 'curiosity_evoking', 'critical_reasoning_needed',
       'inquiry_learning_scope', 'example_availability']).sum()
# Out:
# np.int64(10)

# %%
df[df['next_section']=='Concept Definition'].duplicated(subset=['next_section','difficulty',
       'board_exam_importance', 'olympiad_importance', 'avg_study_time_min',
       'interest_evoking', 'curiosity_evoking', 'critical_reasoning_needed',
       'inquiry_learning_scope', 'example_availability']).sum()
# Out:
# np.int64(86)
