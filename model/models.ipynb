# %%
import pandas as pd
import numpy as np
import ast
from sklearn.preprocessing import MultiLabelBinarizer

# %%
df = pd.read_csv('langchain_student_params_v3.csv')

# %%
df.columns
# Out:
# Index(['conceptual_clarity_level', 'attention_span_category',
#        'retention_strength', 'problem_solving_speed_sec', 'error_pattern',
#        'growth_slope', 'response_to_feedback', 'revisions_per_week',
#        'days_between_revisions', 'method_of_revision',
#        'question_asking_nature', 'self_assessment_accuracy',
#        'exploration_tendency', 'teacher_relationship_quality',
#        'peer_learning_behavior', 'communication_clarity',
#        'discussion_engagement', 'test_anxiety_level',
#        'resilience_after_failure', 'motivation_intrinsic_vs_extrinsic',
#        'achievement_orientation', 'emotional_self_awareness',
#        'device_access_type', 'preferred_edtech_apps',
#        'digital_distraction_level', 'input_method_preference',
#        'highest_academic_level', 'study_space_quality',
#        'academic_pressure_at_home', 'family_responsibilities_hrs',
#        'support_system_strength', 'content_type_preference',
#        'knowledge_graph_nodes_covered', 'ongoing_concept',
#        'metacognitive_skill_level', 'next_section', 'difficulty',
#        'board_exam_importance', 'olympiad_importance', 'avg_study_time_min',
#        'interest_evoking', 'curiosity_evoking', 'critical_reasoning_needed',
#        'inquiry_learning_scope', 'example_availability'],
#       dtype='object')

# %%
df = df[['conceptual_clarity_level', 'attention_span_category',
       'retention_strength', 'problem_solving_speed_sec', 'error_pattern',
       'growth_slope', 'response_to_feedback', 'revisions_per_week',
       'days_between_revisions', 'method_of_revision',
       'question_asking_nature', 'self_assessment_accuracy',
       'exploration_tendency', 'teacher_relationship_quality',
       'peer_learning_behavior', 'communication_clarity',
       'discussion_engagement', 'test_anxiety_level',
       'resilience_after_failure', 'motivation_intrinsic_vs_extrinsic',
       'achievement_orientation', 'emotional_self_awareness',
       'device_access_type', 'preferred_edtech_apps',
       'digital_distraction_level', 'input_method_preference',
       'highest_academic_level', 'study_space_quality',
       'academic_pressure_at_home', 'family_responsibilities_hrs',
       'support_system_strength', 'content_type_preference',
       'knowledge_graph_nodes_covered', 'ongoing_concept',
       'metacognitive_skill_level','next_section']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2456 entries, 0 to 2455
# Data columns (total 36 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   conceptual_clarity_level           2456 non-null   int64
#  1   attention_span_category            2456 non-null   int64
#  2   retention_strength                 2456 non-null   float64
#  3   problem_solving_speed_sec          2456 non-null   int64
#  4   error_pattern                      2456 non-null   object
#  5   growth_slope                       2456 non-null   float64
#  6   response_to_feedback               2456 non-null   int64
#  7   revisions_per_week                 2456 non-null   int64
#  8   days_between_revisions             2456 non-null   int64
#  9   method_of_revision                 2456 non-null   object
#  10  question_asking_nature             2456 non-null   int64
#  11  self_assessment_accuracy           2456 non-null   float64
#  12  exploration_tendency               2456 non-null   int64
#  13  teacher_relationship_quality       2456 non-null   int64
#  14  peer_learning_behavior             2456 non-null   int64
#  15  communication_clarity              2456 non-null   int64
#  16  discussion_engagement              2456 non-null   int64
#  17  test_anxiety_level                 2456 non-null   int64
#  18  resilience_after_failure           2456 non-null   int64
#  19  motivation_intrinsic_vs_extrinsic  2456 non-null   float64
#  20  achievement_orientation            2456 non-null   int64
#  21  emotional_self_awareness           2456 non-null   int64
#  22  device_access_type                 2456 non-null   int64
#  23  preferred_edtech_apps              2456 non-null   object
#  24  digital_distraction_level          2456 non-null   int64
#  25  input_method_preference            2456 non-null   object
#  26  highest_academic_level             2456 non-null   object
#  27  study_space_quality                2456 non-null   int64
#  28  academic_pressure_at_home          2456 non-null   int64
#  29  family_responsibilities_hrs        2456 non-null   int64
#  30  support_system_strength            2456 non-null   int64
#  31  content_type_preference            2456 non-null   object
#  32  knowledge_graph_nodes_covered      2456 non-null   object
#  33  ongoing_concept                    2456 non-null   object
#  34  metacognitive_skill_level          2456 non-null   int64
#  35  next_section                       2456 non-null   object
# dtypes: float64(4), int64(23), object(9)
# memory usage: 690.9+ KB

# %%
df.drop(columns=['next_section']).duplicated().sum()
# Out:
# 46

# %%
df = df.drop_duplicates(subset=['conceptual_clarity_level', 'attention_span_category',
       'retention_strength', 'problem_solving_speed_sec', 'error_pattern',
       'growth_slope', 'response_to_feedback', 'revisions_per_week',
       'days_between_revisions', 'method_of_revision',
       'question_asking_nature', 'self_assessment_accuracy',
       'exploration_tendency', 'teacher_relationship_quality',
       'peer_learning_behavior', 'communication_clarity',
       'discussion_engagement', 'test_anxiety_level',
       'resilience_after_failure', 'motivation_intrinsic_vs_extrinsic',
       'achievement_orientation', 'emotional_self_awareness',
       'device_access_type', 'preferred_edtech_apps',
       'digital_distraction_level', 'input_method_preference',
       'highest_academic_level', 'study_space_quality',
       'academic_pressure_at_home', 'family_responsibilities_hrs',
       'support_system_strength', 'content_type_preference',
       'knowledge_graph_nodes_covered', 'ongoing_concept',
       'metacognitive_skill_level'],keep = False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2410 entries, 0 to 2455
# Data columns (total 36 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   conceptual_clarity_level           2410 non-null   int64
#  1   attention_span_category            2410 non-null   int64
#  2   retention_strength                 2410 non-null   float64
#  3   problem_solving_speed_sec          2410 non-null   int64
#  4   error_pattern                      2410 non-null   object
#  5   growth_slope                       2410 non-null   float64
#  6   response_to_feedback               2410 non-null   int64
#  7   revisions_per_week                 2410 non-null   int64
#  8   days_between_revisions             2410 non-null   int64
#  9   method_of_revision                 2410 non-null   object
#  10  question_asking_nature             2410 non-null   int64
#  11  self_assessment_accuracy           2410 non-null   float64
#  12  exploration_tendency               2410 non-null   int64
#  13  teacher_relationship_quality       2410 non-null   int64
#  14  peer_learning_behavior             2410 non-null   int64
#  15  communication_clarity              2410 non-null   int64
#  16  discussion_engagement              2410 non-null   int64
#  17  test_anxiety_level                 2410 non-null   int64
#  18  resilience_after_failure           2410 non-null   int64
#  19  motivation_intrinsic_vs_extrinsic  2410 non-null   float64
#  20  achievement_orientation            2410 non-null   int64
#  21  emotional_self_awareness           2410 non-null   int64
#  22  device_access_type                 2410 non-null   int64
#  23  preferred_edtech_apps              2410 non-null   object
#  24  digital_distraction_level          2410 non-null   int64
#  25  input_method_preference            2410 non-null   object
#  26  highest_academic_level             2410 non-null   object
#  27  study_space_quality                2410 non-null   int64
#  28  academic_pressure_at_home          2410 non-null   int64
#  29  family_responsibilities_hrs        2410 non-null   int64
#  30  support_system_strength            2410 non-null   int64
#  31  content_type_preference            2410 non-null   object
#  32  knowledge_graph_nodes_covered      2410 non-null   object
#  33  ongoing_concept                    2410 non-null   object
#  34  metacognitive_skill_level          2410 non-null   int64
#  35  next_section                       2410 non-null   object
# dtypes: float64(4), int64(23), object(9)
# memory usage: 696.6+ KB

# %%
X = df.drop(columns = 'next_section')
y = df['next_section']

# %% [markdown]
# # One-Hot Encoding Columns

# %%
for i in X.columns:
    if X[i].dtype == 'object':
        print(f"Column {i} is of type object")
# Out:
# Column error_pattern is of type object
# Column method_of_revision is of type object
# Column preferred_edtech_apps is of type object
# Column input_method_preference is of type object
# Column highest_academic_level is of type object
# Column content_type_preference is of type object
# Column knowledge_graph_nodes_covered is of type object
# Column ongoing_concept is of type object

# %%
X = pd.get_dummies(X, columns=['error_pattern', 'input_method_preference', 'highest_academic_level', 'ongoing_concept'])

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2410 entries, 0 to 2455
# Data columns (total 52 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   conceptual_clarity_level                   2410 non-null   int64
#  1   attention_span_category                    2410 non-null   int64
#  2   retention_strength                         2410 non-null   float64
#  3   problem_solving_speed_sec                  2410 non-null   int64
#  4   growth_slope                               2410 non-null   float64
#  5   response_to_feedback                       2410 non-null   int64
#  6   revisions_per_week                         2410 non-null   int64
#  7   days_between_revisions                     2410 non-null   int64
#  8   method_of_revision                         2410 non-null   object
#  9   question_asking_nature                     2410 non-null   int64
#  10  self_assessment_accuracy                   2410 non-null   float64
#  11  exploration_tendency                       2410 non-null   int64
#  12  teacher_relationship_quality               2410 non-null   int64
#  13  peer_learning_behavior                     2410 non-null   int64
#  14  communication_clarity                      2410 non-null   int64
#  15  discussion_engagement                      2410 non-null   int64
#  16  test_anxiety_level                         2410 non-null   int64
#  17  resilience_after_failure                   2410 non-null   int64
#  18  motivation_intrinsic_vs_extrinsic          2410 non-null   float64
#  19  achievement_orientation                    2410 non-null   int64
#  20  emotional_self_awareness                   2410 non-null   int64
#  21  device_access_type                         2410 non-null   int64
#  22  preferred_edtech_apps                      2410 non-null   object
#  23  digital_distraction_level                  2410 non-null   int64
#  24  study_space_quality                        2410 non-null   int64
#  25  academic_pressure_at_home                  2410 non-null   int64
#  26  family_responsibilities_hrs                2410 non-null   int64
#  27  support_system_strength                    2410 non-null   int64
#  28  content_type_preference                    2410 non-null   object
#  29  knowledge_graph_nodes_covered              2410 non-null   object
#  30  metacognitive_skill_level                  2410 non-null   int64
#  31  error_pattern_calculation                  2410 non-null   bool
#  32  error_pattern_careless                     2410 non-null   bool
#  33  error_pattern_conceptual                   2410 non-null   bool
#  34  input_method_preference_typing             2410 non-null   bool
#  35  input_method_preference_writing            2410 non-null   bool
#  36  highest_academic_level_bachelor            2410 non-null   bool
#  37  highest_academic_level_high_school         2410 non-null   bool
#  38  highest_academic_level_master              2410 non-null   bool
#  39  highest_academic_level_middle_school       2410 non-null   bool
#  40  highest_academic_level_phd                 2410 non-null   bool
#  41  highest_academic_level_primary_school      2410 non-null   bool
#  42  ongoing_concept_Candle Clock               2410 non-null   bool
#  43  ongoing_concept_Hourglass                  2410 non-null   bool
#  44  ongoing_concept_Non-uniform Linear Motion  2410 non-null   bool
#  45  ongoing_concept_SI Unit of Time            2410 non-null   bool
#  46  ongoing_concept_Simple Pendulum            2410 non-null   bool
#  47  ongoing_concept_Speed                      2410 non-null   bool
#  48  ongoing_concept_Sundial                    2410 non-null   bool
#  49  ongoing_concept_Time Period of Pendulum    2410 non-null   bool
#  50  ongoing_concept_Uniform Linear Motion      2410 non-null   bool
#  51  ongoing_concept_Water Clock                2410 non-null   bool
# dtypes: bool(21), float64(4), int64(23), object(4)
# memory usage: 651.9+ KB

# %%
multi_label_cols = ['method_of_revision', 'preferred_edtech_apps','content_type_preference','knowledge_graph_nodes_covered']  # add other columns here

# 4. Convert and binarize each multi-label column
for col in multi_label_cols:
    # Parse string representation of lists into actual Python lists
    X[col] = X[col].apply(ast.literal_eval)
    
    # Binarize
    mlb = MultiLabelBinarizer()
    multi_dummies = mlb.fit_transform(X[col])

    # Create DataFrame of dummy columns with a prefix
    dummy_X = pd.DataFrame(
        multi_dummies,
        columns=[f"{col}_{c}" for c in mlb.classes_],
        index=X.index
    )
    
    # Join and drop original
    X = X.join(dummy_X).drop(columns=[col])

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2410 entries, 0 to 2455
# Data columns (total 83 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   conceptual_clarity_level                               2410 non-null   int64
#  1   attention_span_category                                2410 non-null   int64
#  2   retention_strength                                     2410 non-null   float64
#  3   problem_solving_speed_sec                              2410 non-null   int64
#  4   growth_slope                                           2410 non-null   float64
#  5   response_to_feedback                                   2410 non-null   int64
#  6   revisions_per_week                                     2410 non-null   int64
#  7   days_between_revisions                                 2410 non-null   int64
#  8   question_asking_nature                                 2410 non-null   int64
#  9   self_assessment_accuracy                               2410 non-null   float64
#  10  exploration_tendency                                   2410 non-null   int64
#  11  teacher_relationship_quality                           2410 non-null   int64
#  12  peer_learning_behavior                                 2410 non-null   int64
#  13  communication_clarity                                  2410 non-null   int64
#  14  discussion_engagement                                  2410 non-null   int64
#  15  test_anxiety_level                                     2410 non-null   int64
#  16  resilience_after_failure                               2410 non-null   int64
#  17  motivation_intrinsic_vs_extrinsic                      2410 non-null   float64
#  18  achievement_orientation                                2410 non-null   int64
#  19  emotional_self_awareness                               2410 non-null   int64
#  20  device_access_type                                     2410 non-null   int64
#  21  digital_distraction_level                              2410 non-null   int64
#  22  study_space_quality                                    2410 non-null   int64
#  23  academic_pressure_at_home                              2410 non-null   int64
#  24  family_responsibilities_hrs                            2410 non-null   int64
#  25  support_system_strength                                2410 non-null   int64
#  26  metacognitive_skill_level                              2410 non-null   int64
#  27  error_pattern_calculation                              2410 non-null   bool
#  28  error_pattern_careless                                 2410 non-null   bool
#  29  error_pattern_conceptual                               2410 non-null   bool
#  30  input_method_preference_typing                         2410 non-null   bool
#  31  input_method_preference_writing                        2410 non-null   bool
#  32  highest_academic_level_bachelor                        2410 non-null   bool
#  33  highest_academic_level_high_school                     2410 non-null   bool
#  34  highest_academic_level_master                          2410 non-null   bool
#  35  highest_academic_level_middle_school                   2410 non-null   bool
#  36  highest_academic_level_phd                             2410 non-null   bool
#  37  highest_academic_level_primary_school                  2410 non-null   bool
#  38  ongoing_concept_Candle Clock                           2410 non-null   bool
#  39  ongoing_concept_Hourglass                              2410 non-null   bool
#  40  ongoing_concept_Non-uniform Linear Motion              2410 non-null   bool
#  41  ongoing_concept_SI Unit of Time                        2410 non-null   bool
#  42  ongoing_concept_Simple Pendulum                        2410 non-null   bool
#  43  ongoing_concept_Speed                                  2410 non-null   bool
#  44  ongoing_concept_Sundial                                2410 non-null   bool
#  45  ongoing_concept_Time Period of Pendulum                2410 non-null   bool
#  46  ongoing_concept_Uniform Linear Motion                  2410 non-null   bool
#  47  ongoing_concept_Water Clock                            2410 non-null   bool
#  48  method_of_revision_active_recall                       2410 non-null   int32
#  49  method_of_revision_flashcards                          2410 non-null   int32
#  50  method_of_revision_group_study                         2410 non-null   int32
#  51  method_of_revision_mnemonics                           2410 non-null   int32
#  52  method_of_revision_practice_tests                      2410 non-null   int32
#  53  method_of_revision_spaced_repetition                   2410 non-null   int32
#  54  method_of_revision_summarization                       2410 non-null   int32
#  55  preferred_edtech_apps_Brainly                          2410 non-null   int32
#  56  preferred_edtech_apps_Desmos                           2410 non-null   int32
#  57  preferred_edtech_apps_GeoGebra                         2410 non-null   int32
#  58  preferred_edtech_apps_KhanAcademy                      2410 non-null   int32
#  59  preferred_edtech_apps_Quizlet                          2410 non-null   int32
#  60  preferred_edtech_apps_Wikipedia                        2410 non-null   int32
#  61  preferred_edtech_apps_WolframAlpha                     2410 non-null   int32
#  62  preferred_edtech_apps_YouTube                          2410 non-null   int32
#  63  preferred_edtech_apps_brilliant                        2410 non-null   int32
#  64  preferred_edtech_apps_desmos                           2410 non-null   int32
#  65  preferred_edtech_apps_khanacademy                      2410 non-null   int32
#  66  preferred_edtech_apps_quizlet                          2410 non-null   int32
#  67  preferred_edtech_apps_wikipedia                        2410 non-null   int32
#  68  preferred_edtech_apps_wolframalpha                     2410 non-null   int32
#  69  preferred_edtech_apps_youtube                          2410 non-null   int32
#  70  content_type_preference_gamified                       2410 non-null   int32
#  71  content_type_preference_simulation                     2410 non-null   int32
#  72  content_type_preference_text                           2410 non-null   int32
#  73  content_type_preference_video                          2410 non-null   int32
#  74  knowledge_graph_nodes_covered_Candle Clock             2410 non-null   int32
#  75  knowledge_graph_nodes_covered_Hourglass                2410 non-null   int32
#  76  knowledge_graph_nodes_covered_SI Unit of Time          2410 non-null   int32
#  77  knowledge_graph_nodes_covered_Simple Pendulum          2410 non-null   int32
#  78  knowledge_graph_nodes_covered_Speed                    2410 non-null   int32
#  79  knowledge_graph_nodes_covered_Sundial                  2410 non-null   int32
#  80  knowledge_graph_nodes_covered_Time Period of Pendulum  2410 non-null   int32
#  81  knowledge_graph_nodes_covered_Uniform Linear Motion    2410 non-null   int32
#  82  knowledge_graph_nodes_covered_Water Clock              2410 non-null   int32
# dtypes: bool(21), float64(4), int32(35), int64(23)
# memory usage: 906.1 KB

# %% [markdown]
# # train-test-split(stratified)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

# %% [markdown]
# # Removing redundant columns to perform class balancing later

# %%
for D in (X_train, X_test):
    bools = D.select_dtypes(include=['bool']).columns
    D[bools] = D[bools].astype(int)

# %%
def correlation_filter(X, threshold=0.9):
    corr_matrix = X.corr().abs()
    upper_tri = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
    to_drop = [col for col in upper_tri.columns if any(upper_tri[col] > threshold)]
    return to_drop

# %%
drop_corr = correlation_filter(X_train, threshold=0.9)
X_train_reduced = X_train.drop(columns=drop_corr)
X_test_reduced = X_test.drop(columns=drop_corr)

# %%
def calculate_vif(X):
    vif_data = pd.DataFrame()
    vif_data['feature'] = X.columns
    vif_data['VIF'] = [
        variance_inflation_factor(X.values, i) 
        for i in range(X.shape[1])
    ]
    return vif_data

# %%
max_vif = 10
from statsmodels.stats.outliers_influence import variance_inflation_factor
while True:
    vif_df = calculate_vif(X_train_reduced)
    highest_vif = vif_df['VIF'].max()
    if highest_vif > max_vif:
        # Drop the feature with highest VIF
        drop_feature = vif_df.sort_values('VIF', ascending=False)['feature'].iloc[0]
        X_train_reduced = X_train_reduced.drop(columns=[drop_feature])
        X_test_reduced = X_test_reduced.drop(columns=[drop_feature])
    else:
        break
# Out:
# c:\micromamba\envs\ml\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\micromamba\envs\ml\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\micromamba\envs\ml\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\micromamba\envs\ml\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\micromamba\envs\ml\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# c:\micromamba\envs\ml\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)

# %%
X_train_reduced.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1928 entries, 380 to 1446
# Data columns (total 29 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   error_pattern_calculation                  1928 non-null   int32
#  1   input_method_preference_typing             1928 non-null   int32
#  2   highest_academic_level_master              1928 non-null   int32
#  3   highest_academic_level_middle_school       1928 non-null   int32
#  4   highest_academic_level_phd                 1928 non-null   int32
#  5   ongoing_concept_Candle Clock               1928 non-null   int32
#  6   ongoing_concept_Hourglass                  1928 non-null   int32
#  7   ongoing_concept_Non-uniform Linear Motion  1928 non-null   int32
#  8   ongoing_concept_SI Unit of Time            1928 non-null   int32
#  9   ongoing_concept_Simple Pendulum            1928 non-null   int32
#  10  ongoing_concept_Speed                      1928 non-null   int32
#  11  ongoing_concept_Time Period of Pendulum    1928 non-null   int32
#  12  ongoing_concept_Uniform Linear Motion      1928 non-null   int32
#  13  method_of_revision_group_study             1928 non-null   int32
#  14  method_of_revision_mnemonics               1928 non-null   int32
#  15  method_of_revision_summarization           1928 non-null   int32
#  16  preferred_edtech_apps_Desmos               1928 non-null   int32
#  17  preferred_edtech_apps_GeoGebra             1928 non-null   int32
#  18  preferred_edtech_apps_KhanAcademy          1928 non-null   int32
#  19  preferred_edtech_apps_Quizlet              1928 non-null   int32
#  20  preferred_edtech_apps_Wikipedia            1928 non-null   int32
#  21  preferred_edtech_apps_WolframAlpha         1928 non-null   int32
#  22  preferred_edtech_apps_brilliant            1928 non-null   int32
#  23  preferred_edtech_apps_desmos               1928 non-null   int32
#  24  preferred_edtech_apps_quizlet              1928 non-null   int32
#  25  preferred_edtech_apps_wikipedia            1928 non-null   int32
#  26  preferred_edtech_apps_wolframalpha         1928 non-null   int32
#  27  preferred_edtech_apps_youtube              1928 non-null   int32
#  28  content_type_preference_text               1928 non-null   int32
# dtypes: int32(29)
# memory usage: 233.5 KB

# %% [markdown]
# # Applying the models

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (
    RandomForestClassifier, ExtraTreesClassifier,
    GradientBoostingClassifier, HistGradientBoostingClassifier,
    AdaBoostClassifier, BaggingClassifier
)
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from imblearn.over_sampling import (
    RandomOverSampler, SMOTE, BorderlineSMOTE, SVMSMOTE, ADASYN
)
# from imblearn.under_sampling import RandomUnderSampler, ClusterCentroids
# from imblearn.combine import SMOTEENN, SMOTETomek
# from imblearn.ensemble import EasyEnsembleClassifier
from sklearn.metrics import accuracy_score
from catboost import CatBoostClassifier
import ast
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.preprocessing import LabelEncoder,StandardScaler

# === Part 1: Oversampled classifiers on X_train_reduced/X_test_reduced ===

le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)

scaler = StandardScaler()
X_train_reduced = scaler.fit_transform(X_train_reduced)
X_test_reduced = scaler.transform(X_test_reduced)

samplers = {
    'NoSampling': None,
    'RandomOverSampler': RandomOverSampler(random_state=42),
    'SMOTE': SMOTE(k_neighbors=3,random_state=42),
    'BorderlineSMOTE': BorderlineSMOTE(random_state=42),
    # 'SVMSMOTE': SVMSMOTE(random_state=42),
    'ADASYN': ADASYN(n_neighbors=3, random_state=42)
}

models = {
    'DecisionTree': DecisionTreeClassifier(random_state=42),
    'RandomForest': RandomForestClassifier(n_estimators=100, class_weight='balanced', random_state=42),
    'ExtraTrees': ExtraTreesClassifier(n_estimators=100, class_weight='balanced', random_state=42),
    'GradientBoosting': GradientBoostingClassifier(n_estimators=100, random_state=42),
    'HistGradientBoosting': HistGradientBoostingClassifier(random_state=42),
    'AdaBoost': AdaBoostClassifier(n_estimators=50, random_state=42),
    'Bagging': BaggingClassifier(n_estimators=10, random_state=42),
    'XGBoost': XGBClassifier(eval_metric='mlogloss', random_state=42),
    'LogisticRegression': LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42),
    'SVM': SVC(kernel='rbf', class_weight='balanced', probability=True, random_state=42),
    'KNN': KNeighborsClassifier(n_neighbors=5),
    'GaussianNB': GaussianNB(),
    'MLP': MLPClassifier(hidden_layer_sizes=(100,), max_iter=1000, random_state=42)
}

results = []
trained_models = {}

for samp_name, sampler in samplers.items():
    if sampler:
        X_res, y_res = sampler.fit_resample(X_train_reduced, y_train)
    else:
        X_res, y_res = X_train_reduced, y_train

    for model_name, model in models.items():
        model.fit(X_res, y_res)
        trained_models[(samp_name, model_name)] = model

        y_pred = model.predict(X_test_reduced)
        f1 = f1_score(y_test, y_pred, average='macro')  # or 'weighted'

        results.append({
            'Sampler': samp_name,
            'Model Name':   model_name,
            'Model': model,
            'Accuracy': accuracy_score(y_test, y_pred),
            'Macro F1': f1
        })
        print(f"Trained {model_name} with {samp_name}: macro F₁ = {f1:.4f}, accuracy = {accuracy_score(y_test, y_pred):.4f}")

# Final results table
results_df = pd.DataFrame(results).sort_values(by='Macro F1', ascending=False).reset_index(drop=True)
print("\n=== Combined Results ===")
print(results_df[['Sampler','Model Name','Macro F1','Accuracy']].to_string(index=False))

print("Accuracy based results:")
print(results_df[['Sampler','Model Name','Macro F1','Accuracy']].sort_values(by='Accuracy', ascending=False).to_string(index=False))
# Out:
# Trained DecisionTree with NoSampling: macro F₁ = 0.2188, accuracy = 0.3548
# Trained RandomForest with NoSampling: macro F₁ = 0.2360, accuracy = 0.3257
# Trained ExtraTrees with NoSampling: macro F₁ = 0.2438, accuracy = 0.3278
# Trained GradientBoosting with NoSampling: macro F₁ = 0.2071, accuracy = 0.3506
# Trained HistGradientBoosting with NoSampling: macro F₁ = 0.2100, accuracy = 0.3527
# Trained AdaBoost with NoSampling: macro F₁ = 0.1233, accuracy = 0.2925
# Trained Bagging with NoSampling: macro F₁ = 0.2191, accuracy = 0.3589
# Trained XGBoost with NoSampling: macro F₁ = 0.2100, accuracy = 0.3527
# Trained LogisticRegression with NoSampling: macro F₁ = 0.2410, accuracy = 0.3257
# Trained SVM with NoSampling: macro F₁ = 0.2343, accuracy = 0.3278
# Trained KNN with NoSampling: macro F₁ = 0.2073, accuracy = 0.3195
# Trained GaussianNB with NoSampling: macro F₁ = 0.0716, accuracy = 0.0934
# Trained MLP with NoSampling: macro F₁ = 0.2046, accuracy = 0.3465
# Trained DecisionTree with RandomOverSampler: macro F₁ = 0.2176, accuracy = 0.3050
# Trained RandomForest with RandomOverSampler: macro F₁ = 0.2176, accuracy = 0.3050
# Trained ExtraTrees with RandomOverSampler: macro F₁ = 0.2176, accuracy = 0.3050
# Trained GradientBoosting with RandomOverSampler: macro F₁ = 0.2236, accuracy = 0.3071
# Trained HistGradientBoosting with RandomOverSampler: macro F₁ = 0.2193, accuracy = 0.3050
# Trained AdaBoost with RandomOverSampler: macro F₁ = 0.2005, accuracy = 0.3133
# Trained Bagging with RandomOverSampler: macro F₁ = 0.2178, accuracy = 0.3071
# Trained XGBoost with RandomOverSampler: macro F₁ = 0.2250, accuracy = 0.3071
# Trained LogisticRegression with RandomOverSampler: macro F₁ = 0.2362, accuracy = 0.3174
# Trained SVM with RandomOverSampler: macro F₁ = 0.2228, accuracy = 0.3112
# Trained KNN with RandomOverSampler: macro F₁ = 0.2071, accuracy = 0.3216
# Trained GaussianNB with RandomOverSampler: macro F₁ = 0.0685, accuracy = 0.0913
# Trained MLP with RandomOverSampler: macro F₁ = 0.2279, accuracy = 0.3154
# Trained DecisionTree with SMOTE: macro F₁ = 0.2367, accuracy = 0.3278
# Trained RandomForest with SMOTE: macro F₁ = 0.2239, accuracy = 0.3237
# Trained ExtraTrees with SMOTE: macro F₁ = 0.2367, accuracy = 0.3278
# Trained GradientBoosting with SMOTE: macro F₁ = 0.2425, accuracy = 0.3320
# Trained HistGradientBoosting with SMOTE: macro F₁ = 0.2226, accuracy = 0.3195
# Trained AdaBoost with SMOTE: macro F₁ = 0.2001, accuracy = 0.3029
# Trained Bagging with SMOTE: macro F₁ = 0.2317, accuracy = 0.3278
# Trained XGBoost with SMOTE: macro F₁ = 0.2236, accuracy = 0.3216
# Trained LogisticRegression with SMOTE: macro F₁ = 0.2494, accuracy = 0.3257
# Trained SVM with SMOTE: macro F₁ = 0.2468, accuracy = 0.3299
# Trained KNN with SMOTE: macro F₁ = 0.2099, accuracy = 0.3237
# Trained GaussianNB with SMOTE: macro F₁ = 0.0757, accuracy = 0.0954
# Trained MLP with SMOTE: macro F₁ = 0.2415, accuracy = 0.3257
# Trained DecisionTree with BorderlineSMOTE: macro F₁ = 0.2135, accuracy = 0.3071
# Trained RandomForest with BorderlineSMOTE: macro F₁ = 0.2099, accuracy = 0.3071
# Trained ExtraTrees with BorderlineSMOTE: macro F₁ = 0.2135, accuracy = 0.3071
# Trained GradientBoosting with BorderlineSMOTE: macro F₁ = 0.2167, accuracy = 0.3091
# Trained HistGradientBoosting with BorderlineSMOTE: macro F₁ = 0.2087, accuracy = 0.3029
# Trained AdaBoost with BorderlineSMOTE: macro F₁ = 0.2202, accuracy = 0.3299
# Trained Bagging with BorderlineSMOTE: macro F₁ = 0.2090, accuracy = 0.3050
# Trained XGBoost with BorderlineSMOTE: macro F₁ = 0.2085, accuracy = 0.3029
# Trained LogisticRegression with BorderlineSMOTE: macro F₁ = 0.2249, accuracy = 0.3133
# Trained SVM with BorderlineSMOTE: macro F₁ = 0.2081, accuracy = 0.3008
# Trained KNN with BorderlineSMOTE: macro F₁ = 0.2074, accuracy = 0.3216
# Trained GaussianNB with BorderlineSMOTE: macro F₁ = 0.0869, accuracy = 0.1058
# Trained MLP with BorderlineSMOTE: macro F₁ = 0.2128, accuracy = 0.3029
# Trained DecisionTree with ADASYN: macro F₁ = 0.2076, accuracy = 0.3008
# Trained RandomForest with ADASYN: macro F₁ = 0.2309, accuracy = 0.3278
# Trained ExtraTrees with ADASYN: macro F₁ = 0.2326, accuracy = 0.3278
# Trained GradientBoosting with ADASYN: macro F₁ = 0.2078, accuracy = 0.3008
# Trained HistGradientBoosting with ADASYN: macro F₁ = 0.2060, accuracy = 0.3008
# Trained AdaBoost with ADASYN: macro F₁ = 0.1695, accuracy = 0.3050
# Trained Bagging with ADASYN: macro F₁ = 0.2192, accuracy = 0.3174
# Trained XGBoost with ADASYN: macro F₁ = 0.2097, accuracy = 0.3050
# Trained LogisticRegression with ADASYN: macro F₁ = 0.2483, accuracy = 0.3278
# Trained SVM with ADASYN: macro F₁ = 0.2232, accuracy = 0.3133
# Trained KNN with ADASYN: macro F₁ = 0.2097, accuracy = 0.3195
# Trained GaussianNB with ADASYN: macro F₁ = 0.0751, accuracy = 0.0954
# Trained MLP with ADASYN: macro F₁ = 0.2062, accuracy = 0.3029
#
# === Combined Results ===
#           Sampler           Model Name  Macro F1  Accuracy
#             SMOTE   LogisticRegression  0.249399  0.325726
#            ADASYN   LogisticRegression  0.248347  0.327801
#             SMOTE                  SVM  0.246751  0.329876
#        NoSampling           ExtraTrees  0.243820  0.327801
#             SMOTE     GradientBoosting  0.242501  0.331950
#             SMOTE                  MLP  0.241475  0.325726
#        NoSampling   LogisticRegression  0.241026  0.325726
#             SMOTE         DecisionTree  0.236671  0.327801
#             SMOTE           ExtraTrees  0.236671  0.327801
# RandomOverSampler   LogisticRegression  0.236218  0.317427
#        NoSampling         RandomForest  0.235998  0.325726
#        NoSampling                  SVM  0.234277  0.327801
#            ADASYN           ExtraTrees  0.232561  0.327801
#             SMOTE              Bagging  0.231715  0.327801
#            ADASYN         RandomForest  0.230869  0.327801
# RandomOverSampler                  MLP  0.227917  0.315353
# RandomOverSampler              XGBoost  0.224988  0.307054
#   BorderlineSMOTE   LogisticRegression  0.224877  0.313278
#             SMOTE         RandomForest  0.223884  0.323651
# RandomOverSampler     GradientBoosting  0.223574  0.307054
#             SMOTE              XGBoost  0.223551  0.321577
#            ADASYN                  SVM  0.223177  0.313278
# RandomOverSampler                  SVM  0.222766  0.311203
#             SMOTE HistGradientBoosting  0.222578  0.319502
#   BorderlineSMOTE             AdaBoost  0.220233  0.329876
# RandomOverSampler HistGradientBoosting  0.219302  0.304979
#            ADASYN              Bagging  0.219189  0.317427
#        NoSampling              Bagging  0.219116  0.358921
#        NoSampling         DecisionTree  0.218828  0.354772
# RandomOverSampler              Bagging  0.217753  0.307054
# RandomOverSampler           ExtraTrees  0.217559  0.304979
# RandomOverSampler         RandomForest  0.217559  0.304979
# RandomOverSampler         DecisionTree  0.217559  0.304979
#   BorderlineSMOTE     GradientBoosting  0.216729  0.309129
#   BorderlineSMOTE         DecisionTree  0.213535  0.307054
#   BorderlineSMOTE           ExtraTrees  0.213535  0.307054
#   BorderlineSMOTE                  MLP  0.212784  0.302905
#        NoSampling HistGradientBoosting  0.209951  0.352697
#        NoSampling              XGBoost  0.209951  0.352697
#   BorderlineSMOTE         RandomForest  0.209906  0.307054
#             SMOTE                  KNN  0.209885  0.323651
#            ADASYN              XGBoost  0.209729  0.304979
#            ADASYN                  KNN  0.209670  0.319502
#   BorderlineSMOTE              Bagging  0.208983  0.304979
#   BorderlineSMOTE HistGradientBoosting  0.208655  0.302905
#   BorderlineSMOTE              XGBoost  0.208507  0.302905
#   BorderlineSMOTE                  SVM  0.208057  0.300830
#            ADASYN     GradientBoosting  0.207781  0.300830
#            ADASYN         DecisionTree  0.207594  0.300830
#   BorderlineSMOTE                  KNN  0.207356  0.321577
#        NoSampling                  KNN  0.207274  0.319502
# RandomOverSampler                  KNN  0.207148  0.321577
#        NoSampling     GradientBoosting  0.207119  0.350622
#            ADASYN                  MLP  0.206235  0.302905
#            ADASYN HistGradientBoosting  0.206012  0.300830
#        NoSampling                  MLP  0.204587  0.346473
# RandomOverSampler             AdaBoost  0.200549  0.313278
#             SMOTE             AdaBoost  0.200132  0.302905
#            ADASYN             AdaBoost  0.169492  0.304979
#        NoSampling             AdaBoost  0.123286  0.292531
#   BorderlineSMOTE           GaussianNB  0.086894  0.105809
#             SMOTE           GaussianNB  0.075721  0.095436
#            ADASYN           GaussianNB  0.075120  0.095436
#        NoSampling           GaussianNB  0.071622  0.093361
# RandomOverSampler           GaussianNB  0.068543  0.091286
# Accuracy based results:
#           Sampler           Model Name  Macro F1  Accuracy
#        NoSampling              Bagging  0.219116  0.358921
#        NoSampling         DecisionTree  0.218828  0.354772
#        NoSampling HistGradientBoosting  0.209951  0.352697
#        NoSampling              XGBoost  0.209951  0.352697
#        NoSampling     GradientBoosting  0.207119  0.350622
#        NoSampling                  MLP  0.204587  0.346473
#             SMOTE     GradientBoosting  0.242501  0.331950
#             SMOTE                  SVM  0.246751  0.329876
#   BorderlineSMOTE             AdaBoost  0.220233  0.329876
#            ADASYN           ExtraTrees  0.232561  0.327801
#            ADASYN   LogisticRegression  0.248347  0.327801
#            ADASYN         RandomForest  0.230869  0.327801
#             SMOTE              Bagging  0.231715  0.327801
#        NoSampling                  SVM  0.234277  0.327801
#             SMOTE           ExtraTrees  0.236671  0.327801
#             SMOTE         DecisionTree  0.236671  0.327801
#        NoSampling           ExtraTrees  0.243820  0.327801
#        NoSampling         RandomForest  0.235998  0.325726
#        NoSampling   LogisticRegression  0.241026  0.325726
#             SMOTE                  MLP  0.241475  0.325726
#             SMOTE   LogisticRegression  0.249399  0.325726
#             SMOTE                  KNN  0.209885  0.323651
#             SMOTE         RandomForest  0.223884  0.323651
# RandomOverSampler                  KNN  0.207148  0.321577
#             SMOTE              XGBoost  0.223551  0.321577
#   BorderlineSMOTE                  KNN  0.207356  0.321577
#            ADASYN                  KNN  0.209670  0.319502
#        NoSampling                  KNN  0.207274  0.319502
#             SMOTE HistGradientBoosting  0.222578  0.319502
#            ADASYN              Bagging  0.219189  0.317427
# RandomOverSampler   LogisticRegression  0.236218  0.317427
# RandomOverSampler                  MLP  0.227917  0.315353
# RandomOverSampler             AdaBoost  0.200549  0.313278
#            ADASYN                  SVM  0.223177  0.313278
#   BorderlineSMOTE   LogisticRegression  0.224877  0.313278
# RandomOverSampler                  SVM  0.222766  0.311203
#   BorderlineSMOTE     GradientBoosting  0.216729  0.309129
# RandomOverSampler              Bagging  0.217753  0.307054
#   BorderlineSMOTE         DecisionTree  0.213535  0.307054
#   BorderlineSMOTE           ExtraTrees  0.213535  0.307054
# RandomOverSampler     GradientBoosting  0.223574  0.307054
#   BorderlineSMOTE         RandomForest  0.209906  0.307054
# RandomOverSampler              XGBoost  0.224988  0.307054
#            ADASYN             AdaBoost  0.169492  0.304979
# RandomOverSampler         DecisionTree  0.217559  0.304979
# RandomOverSampler         RandomForest  0.217559  0.304979
# RandomOverSampler HistGradientBoosting  0.219302  0.304979
# RandomOverSampler           ExtraTrees  0.217559  0.304979
#   BorderlineSMOTE              Bagging  0.208983  0.304979
#            ADASYN              XGBoost  0.209729  0.304979
#            ADASYN                  MLP  0.206235  0.302905
#             SMOTE             AdaBoost  0.200132  0.302905
#   BorderlineSMOTE              XGBoost  0.208507  0.302905
#   BorderlineSMOTE                  MLP  0.212784  0.302905
#   BorderlineSMOTE HistGradientBoosting  0.208655  0.302905
#            ADASYN HistGradientBoosting  0.206012  0.300830
#   BorderlineSMOTE                  SVM  0.208057  0.300830
#            ADASYN         DecisionTree  0.207594  0.300830
#            ADASYN     GradientBoosting  0.207781  0.300830
#        NoSampling             AdaBoost  0.123286  0.292531
#   BorderlineSMOTE           GaussianNB  0.086894  0.105809
#             SMOTE           GaussianNB  0.075721  0.095436
#            ADASYN           GaussianNB  0.075120  0.095436
#        NoSampling           GaussianNB  0.071622  0.093361
# RandomOverSampler           GaussianNB  0.068543  0.091286

# %%
# === Part 2: CatBoost on original X/y ===
df = pd.read_csv('/mnt/data/langchain_student_params_1300.csv').dropna()

# Binarize multi-label columns
ml_cols = ['method_of_revision','preferred_edtech_apps','knowledge_graph_nodes_covered']
for col in ml_cols:
    df[col] = df[col].apply(ast.literal_eval)
    mlb = MultiLabelBinarizer()
    dummies = mlb.fit_transform(df[col])
    df = df.join(pd.DataFrame(dummies,
                              columns=[f"{col}_{lbl}" for lbl in mlb.classes_],
                              index=df.index)).drop(columns=[col])

# Convert booleans to ints
bool_cols = df.select_dtypes(include=['bool']).columns
df[bool_cols] = df[bool_cols].astype(int)

# Split for CatBoost
X2 = df.drop(columns=['next_section'])
y2 = df['next_section'].astype('category').cat.codes
X2_train, X2_test, y2_train, y2_test = train_test_split(
    X2, y2, stratify=y2, test_size=0.2, random_state=42
)

# Train CatBoost
cat_features = X2_train.select_dtypes(include=['object','category']).columns.tolist()
cb = CatBoostClassifier(iterations=500, learning_rate=0.05, depth=6,
                        eval_metric='Accuracy', random_seed=42, verbose=False)
cb.fit(X2_train, y2_train, cat_features=cat_features, eval_set=(X2_test, y2_test))
trained_models[('NoSampling', 'CatBoost')] = cb
y2_pred = cb.predict(X2_test)
cb_acc = accuracy_score(y2_test, y2_pred)
results.append({'Sampler': 'NoSampling', 'Model': 'CatBoost', 'Accuracy': cb_acc})
print(f"Trained CatBoost: accuracy = {cb_acc:.4f}")

# Final results table
results_df = pd.DataFrame(results).sort_values(by='Accuracy', ascending=False).reset_index(drop=True)
print("\n=== Combined Results ===")
print(results_df.to_string(index=False))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[68], line 2
#       1 # === Part 2: CatBoost on original X/y ===
# ----> 2 df = pd.read_csv('/mnt/data/langchain_student_params_1300.csv').dropna()
#       4 # Binarize multi-label columns
#       5 ml_cols = ['method_of_revision','preferred_edtech_apps','knowledge_graph_nodes_covered']
#
# File c:\micromamba\envs\ml\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\micromamba\envs\ml\lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\micromamba\envs\ml\lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\micromamba\envs\ml\lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\micromamba\envs\ml\lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/data/langchain_student_params_1300.csv'
