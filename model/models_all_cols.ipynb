# %%
import pandas as pd
import numpy as np
import ast
from sklearn.preprocessing import MultiLabelBinarizer

# %%
df = pd.read_csv('langchain_student_params_1300.csv')

# %%
df.columns
# Out:
# Index(['conceptual_clarity_level', 'attention_span_category',
#        'retention_strength', 'problem_solving_speed_sec', 'error_pattern',
#        'growth_slope', 'response_to_feedback', 'revisions_per_week',
#        'days_between_revisions', 'method_of_revision',
#        'question_asking_nature', 'self_assessment_accuracy',
#        'exploration_tendency', 'teacher_relationship_quality',
#        'peer_learning_behavior', 'communication_clarity',
#        'discussion_engagement', 'test_anxiety_level',
#        'resilience_after_failure', 'motivation_intrinsic_vs_extrinsic',
#        'achievement_orientation', 'emotional_self_awareness',
#        'device_access_type', 'preferred_edtech_apps',
#        'digital_distraction_level', 'input_method_preference',
#        'highest_academic_level', 'study_space_quality',
#        'academic_pressure_at_home', 'family_responsibilities_hrs',
#        'support_system_strength', 'content_type_preference',
#        'knowledge_graph_nodes_covered', 'ongoing_concept',
#        'metacognitive_skill_level', 'next_section', 'difficulty',
#        'board_exam_importance', 'olympiad_importance', 'avg_study_time_min',
#        'interest_evoking', 'curiosity_evoking', 'critical_reasoning_needed',
#        'inquiry_learning_scope', 'example_availability'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 45 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   conceptual_clarity_level           1300 non-null   int64
#  1   attention_span_category            1300 non-null   int64
#  2   retention_strength                 1300 non-null   float64
#  3   problem_solving_speed_sec          1300 non-null   int64
#  4   error_pattern                      1300 non-null   object
#  5   growth_slope                       1300 non-null   float64
#  6   response_to_feedback               1300 non-null   int64
#  7   revisions_per_week                 1300 non-null   int64
#  8   days_between_revisions             1300 non-null   int64
#  9   method_of_revision                 1300 non-null   object
#  10  question_asking_nature             1300 non-null   int64
#  11  self_assessment_accuracy           1300 non-null   float64
#  12  exploration_tendency               1300 non-null   int64
#  13  teacher_relationship_quality       1300 non-null   int64
#  14  peer_learning_behavior             1300 non-null   int64
#  15  communication_clarity              1300 non-null   int64
#  16  discussion_engagement              1300 non-null   int64
#  17  test_anxiety_level                 1300 non-null   int64
#  18  resilience_after_failure           1300 non-null   int64
#  19  motivation_intrinsic_vs_extrinsic  1300 non-null   float64
#  20  achievement_orientation            1300 non-null   int64
#  21  emotional_self_awareness           1300 non-null   int64
#  22  device_access_type                 1300 non-null   int64
#  23  preferred_edtech_apps              1300 non-null   object
#  24  digital_distraction_level          1300 non-null   int64
#  25  input_method_preference            1300 non-null   object
#  26  highest_academic_level             1300 non-null   object
#  27  study_space_quality                1300 non-null   int64
#  28  academic_pressure_at_home          1300 non-null   int64
#  29  family_responsibilities_hrs        1300 non-null   int64
#  30  support_system_strength            1300 non-null   int64
#  31  content_type_preference            1300 non-null   object
#  32  knowledge_graph_nodes_covered      1300 non-null   object
#  33  ongoing_concept                    1300 non-null   object
#  34  metacognitive_skill_level          1300 non-null   int64
#  35  next_section                       1300 non-null   object
#  36  difficulty                         1300 non-null   int64
#  37  board_exam_importance              1300 non-null   int64
#  38  olympiad_importance                1300 non-null   int64
#  39  avg_study_time_min                 1300 non-null   int64
#  40  interest_evoking                   1300 non-null   int64
#  41  curiosity_evoking                  1300 non-null   int64
#  42  critical_reasoning_needed          1300 non-null   int64
#  43  inquiry_learning_scope             1300 non-null   int64
#  44  example_availability               1300 non-null   int64
# dtypes: float64(4), int64(32), object(9)
# memory usage: 457.2+ KB

# %%
X = df.drop(columns = 'next_section')
y = df['next_section']

# %% [markdown]
# # One-Hot Encoding Columns

# %%
for i in X.columns:
    if X[i].dtype == 'object':
        print(f"Column {i} is of type object")
# Out:
# Column error_pattern is of type object
# Column method_of_revision is of type object
# Column preferred_edtech_apps is of type object
# Column input_method_preference is of type object
# Column highest_academic_level is of type object
# Column content_type_preference is of type object
# Column knowledge_graph_nodes_covered is of type object
# Column ongoing_concept is of type object

# %%
X = pd.get_dummies(X, columns=['error_pattern', 'input_method_preference', 'highest_academic_level', 'ongoing_concept'])

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 57 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   conceptual_clarity_level                   1300 non-null   int64
#  1   attention_span_category                    1300 non-null   int64
#  2   retention_strength                         1300 non-null   float64
#  3   problem_solving_speed_sec                  1300 non-null   int64
#  4   growth_slope                               1300 non-null   float64
#  5   response_to_feedback                       1300 non-null   int64
#  6   revisions_per_week                         1300 non-null   int64
#  7   days_between_revisions                     1300 non-null   int64
#  8   method_of_revision                         1300 non-null   object
#  9   question_asking_nature                     1300 non-null   int64
#  10  self_assessment_accuracy                   1300 non-null   float64
#  11  exploration_tendency                       1300 non-null   int64
#  12  teacher_relationship_quality               1300 non-null   int64
#  13  peer_learning_behavior                     1300 non-null   int64
#  14  communication_clarity                      1300 non-null   int64
#  15  discussion_engagement                      1300 non-null   int64
#  16  test_anxiety_level                         1300 non-null   int64
#  17  resilience_after_failure                   1300 non-null   int64
#  18  motivation_intrinsic_vs_extrinsic          1300 non-null   float64
#  19  achievement_orientation                    1300 non-null   int64
#  20  emotional_self_awareness                   1300 non-null   int64
#  21  device_access_type                         1300 non-null   int64
#  22  preferred_edtech_apps                      1300 non-null   object
#  23  digital_distraction_level                  1300 non-null   int64
#  24  study_space_quality                        1300 non-null   int64
#  25  academic_pressure_at_home                  1300 non-null   int64
#  26  family_responsibilities_hrs                1300 non-null   int64
#  27  support_system_strength                    1300 non-null   int64
#  28  content_type_preference                    1300 non-null   object
#  29  knowledge_graph_nodes_covered              1300 non-null   object
#  30  metacognitive_skill_level                  1300 non-null   int64
#  31  difficulty                                 1300 non-null   int64
#  32  board_exam_importance                      1300 non-null   int64
#  33  olympiad_importance                        1300 non-null   int64
#  34  avg_study_time_min                         1300 non-null   int64
#  35  interest_evoking                           1300 non-null   int64
#  36  curiosity_evoking                          1300 non-null   int64
#  37  critical_reasoning_needed                  1300 non-null   int64
#  38  inquiry_learning_scope                     1300 non-null   int64
#  39  example_availability                       1300 non-null   int64
#  40  error_pattern_calculation                  1300 non-null   bool
#  41  error_pattern_careless                     1300 non-null   bool
#  42  error_pattern_conceptual                   1300 non-null   bool
#  43  input_method_preference_typing             1300 non-null   bool
#  44  input_method_preference_writing            1300 non-null   bool
#  45  highest_academic_level_bachelor            1300 non-null   bool
#  46  highest_academic_level_high_school         1300 non-null   bool
#  47  highest_academic_level_master              1300 non-null   bool
#  48  highest_academic_level_phd                 1300 non-null   bool
#  49  highest_academic_level_primary_school      1300 non-null   bool
#  50  ongoing_concept_Hourglass                  1300 non-null   bool
#  51  ongoing_concept_Non-uniform Linear Motion  1300 non-null   bool
#  52  ongoing_concept_SI Unit of Time            1300 non-null   bool
#  53  ongoing_concept_Speed                      1300 non-null   bool
#  54  ongoing_concept_Time Period of Pendulum    1300 non-null   bool
#  55  ongoing_concept_Uniform Linear Motion      1300 non-null   bool
#  56  ongoing_concept_Water Clock                1300 non-null   bool
# dtypes: bool(17), float64(4), int64(32), object(4)
# memory usage: 428.0+ KB

# %%
multi_label_cols = ['method_of_revision', 'preferred_edtech_apps','content_type_preference','knowledge_graph_nodes_covered']  # add other columns here

# 4. Convert and binarize each multi-label column
for col in multi_label_cols:
    # Parse string representation of lists into actual Python lists
    X[col] = X[col].apply(ast.literal_eval)
    
    # Binarize
    mlb = MultiLabelBinarizer()
    multi_dummies = mlb.fit_transform(X[col])

    # Create DataFrame of dummy columns with a prefix
    dummy_X = pd.DataFrame(
        multi_dummies,
        columns=[f"{col}_{c}" for c in mlb.classes_],
        index=X.index
    )
    
    # Join and drop original
    X = X.join(dummy_X).drop(columns=[col])

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1300 entries, 0 to 1299
# Data columns (total 80 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   conceptual_clarity_level                               1300 non-null   int64
#  1   attention_span_category                                1300 non-null   int64
#  2   retention_strength                                     1300 non-null   float64
#  3   problem_solving_speed_sec                              1300 non-null   int64
#  4   growth_slope                                           1300 non-null   float64
#  5   response_to_feedback                                   1300 non-null   int64
#  6   revisions_per_week                                     1300 non-null   int64
#  7   days_between_revisions                                 1300 non-null   int64
#  8   question_asking_nature                                 1300 non-null   int64
#  9   self_assessment_accuracy                               1300 non-null   float64
#  10  exploration_tendency                                   1300 non-null   int64
#  11  teacher_relationship_quality                           1300 non-null   int64
#  12  peer_learning_behavior                                 1300 non-null   int64
#  13  communication_clarity                                  1300 non-null   int64
#  14  discussion_engagement                                  1300 non-null   int64
#  15  test_anxiety_level                                     1300 non-null   int64
#  16  resilience_after_failure                               1300 non-null   int64
#  17  motivation_intrinsic_vs_extrinsic                      1300 non-null   float64
#  18  achievement_orientation                                1300 non-null   int64
#  19  emotional_self_awareness                               1300 non-null   int64
#  20  device_access_type                                     1300 non-null   int64
#  21  digital_distraction_level                              1300 non-null   int64
#  22  study_space_quality                                    1300 non-null   int64
#  23  academic_pressure_at_home                              1300 non-null   int64
#  24  family_responsibilities_hrs                            1300 non-null   int64
#  25  support_system_strength                                1300 non-null   int64
#  26  metacognitive_skill_level                              1300 non-null   int64
#  27  difficulty                                             1300 non-null   int64
#  28  board_exam_importance                                  1300 non-null   int64
#  29  olympiad_importance                                    1300 non-null   int64
#  30  avg_study_time_min                                     1300 non-null   int64
#  31  interest_evoking                                       1300 non-null   int64
#  32  curiosity_evoking                                      1300 non-null   int64
#  33  critical_reasoning_needed                              1300 non-null   int64
#  34  inquiry_learning_scope                                 1300 non-null   int64
#  35  example_availability                                   1300 non-null   int64
#  36  error_pattern_calculation                              1300 non-null   bool
#  37  error_pattern_careless                                 1300 non-null   bool
#  38  error_pattern_conceptual                               1300 non-null   bool
#  39  input_method_preference_typing                         1300 non-null   bool
#  40  input_method_preference_writing                        1300 non-null   bool
#  41  highest_academic_level_bachelor                        1300 non-null   bool
#  42  highest_academic_level_high_school                     1300 non-null   bool
#  43  highest_academic_level_master                          1300 non-null   bool
#  44  highest_academic_level_phd                             1300 non-null   bool
#  45  highest_academic_level_primary_school                  1300 non-null   bool
#  46  ongoing_concept_Hourglass                              1300 non-null   bool
#  47  ongoing_concept_Non-uniform Linear Motion              1300 non-null   bool
#  48  ongoing_concept_SI Unit of Time                        1300 non-null   bool
#  49  ongoing_concept_Speed                                  1300 non-null   bool
#  50  ongoing_concept_Time Period of Pendulum                1300 non-null   bool
#  51  ongoing_concept_Uniform Linear Motion                  1300 non-null   bool
#  52  ongoing_concept_Water Clock                            1300 non-null   bool
#  53  method_of_revision_active_recall                       1300 non-null   int32
#  54  method_of_revision_flashcards                          1300 non-null   int32
#  55  method_of_revision_group_study                         1300 non-null   int32
#  56  method_of_revision_practice_tests                      1300 non-null   int32
#  57  method_of_revision_spaced_repetition                   1300 non-null   int32
#  58  method_of_revision_summarization                       1300 non-null   int32
#  59  preferred_edtech_apps_Brainly                          1300 non-null   int32
#  60  preferred_edtech_apps_Desmos                           1300 non-null   int32
#  61  preferred_edtech_apps_GeoGebra                         1300 non-null   int32
#  62  preferred_edtech_apps_KhanAcademy                      1300 non-null   int32
#  63  preferred_edtech_apps_Quizlet                          1300 non-null   int32
#  64  preferred_edtech_apps_Wikipedia                        1300 non-null   int32
#  65  preferred_edtech_apps_WolframAlpha                     1300 non-null   int32
#  66  preferred_edtech_apps_YouTube                          1300 non-null   int32
#  67  content_type_preference_gamified                       1300 non-null   int32
#  68  content_type_preference_simulation                     1300 non-null   int32
#  69  content_type_preference_text                           1300 non-null   int32
#  70  content_type_preference_video                          1300 non-null   int32
#  71  knowledge_graph_nodes_covered_Candle Clock             1300 non-null   int32
#  72  knowledge_graph_nodes_covered_Hourglass                1300 non-null   int32
#  73  knowledge_graph_nodes_covered_SI Unit of Time          1300 non-null   int32
#  74  knowledge_graph_nodes_covered_Simple Pendulum          1300 non-null   int32
#  75  knowledge_graph_nodes_covered_Speed                    1300 non-null   int32
#  76  knowledge_graph_nodes_covered_Sundial                  1300 non-null   int32
#  77  knowledge_graph_nodes_covered_Time Period of Pendulum  1300 non-null   int32
#  78  knowledge_graph_nodes_covered_Uniform Linear Motion    1300 non-null   int32
#  79  knowledge_graph_nodes_covered_Water Clock              1300 non-null   int32
# dtypes: bool(17), float64(4), int32(27), int64(32)
# memory usage: 524.4 KB

# %% [markdown]
# # train-test-split(stratified)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

# %% [markdown]
# # Removing redundant columns to perform class balancing later

# %%
# for D in (X_train, X_test):
#     bools = D.select_dtypes(include=['bool']).columns
#     D[bools] = D[bools].astype(int)

# %%
# def correlation_filter(X, threshold=0.9):
#     corr_matrix = X.corr().abs()
#     upper_tri = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
#     to_drop = [col for col in upper_tri.columns if any(upper_tri[col] > threshold)]
#     return to_drop

# %%
# drop_corr = correlation_filter(X_train, threshold=0.9)
# X_train_reduced = X_train.drop(columns=drop_corr)
# X_test_reduced = X_test.drop(columns=drop_corr)

# %%
# def calculate_vif(X):
#     vif_data = pd.DataFrame()
#     vif_data['feature'] = X.columns
#     vif_data['VIF'] = [
#         variance_inflation_factor(X.values, i) 
#         for i in range(X.shape[1])
#     ]
#     return vif_data

# %%
# max_vif = 10
# from statsmodels.stats.outliers_influence import variance_inflation_factor
# while True:
#     vif_df = calculate_vif(X_train_reduced)
#     highest_vif = vif_df['VIF'].max()
#     if highest_vif > max_vif:
#         # Drop the feature with highest VIF
#         drop_feature = vif_df.sort_values('VIF', ascending=False)['feature'].iloc[0]
#         X_train_reduced = X_train_reduced.drop(columns=[drop_feature])
#         X_test_reduced = X_test_reduced.drop(columns=[drop_feature])
#     else:
#         break

# %%
X_train_reduced = X_train.copy()
X_test_reduced = X_test.copy()

# %%
y_train
# Out:
# 1013    Explanation (with analogies)
# 506     Explanation (with analogies)
# 710            Real-Life Application
# 406               Concept Definition
# 1286    Explanation (with analogies)
#                     ...
# 33                Concept Definition
# 1169                       Intuition
# 163                             MCQs
# 1195    Explanation (with analogies)
# 831            Real-Life Application
# Name: next_section, Length: 1040, dtype: object

# %% [markdown]
# # Applying the models

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import (
    RandomForestClassifier, ExtraTreesClassifier,
    GradientBoostingClassifier, HistGradientBoostingClassifier,
    AdaBoostClassifier, BaggingClassifier
)
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from imblearn.over_sampling import (
    RandomOverSampler, SMOTE, BorderlineSMOTE, SVMSMOTE, ADASYN
)
# from imblearn.under_sampling import RandomUnderSampler, ClusterCentroids
# from imblearn.combine import SMOTEENN, SMOTETomek
# from imblearn.ensemble import EasyEnsembleClassifier
from sklearn.metrics import accuracy_score
from catboost import CatBoostClassifier
import ast
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

# === Part 1: Oversampled classifiers on X_train_reduced/X_test_reduced ===

le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test = le.transform(y_test)

samplers = {
    'NoSampling': None,
    'RandomOverSampler': RandomOverSampler(random_state=42),
    'SMOTE': SMOTE(k_neighbors=3,random_state=42),
    'BorderlineSMOTE': BorderlineSMOTE(k_neighbors = 3,random_state=42),
    # 'SVMSMOTE': SVMSMOTE(random_state=42),
    'ADASYN': ADASYN(n_neighbors=3, random_state=42)
}

models = {
    'DecisionTree': DecisionTreeClassifier(random_state=42),
    'RandomForest': RandomForestClassifier(n_estimators=100, class_weight='balanced', random_state=42),
    'ExtraTrees': ExtraTreesClassifier(n_estimators=100, class_weight='balanced', random_state=42),
    'GradientBoosting': GradientBoostingClassifier(n_estimators=100, random_state=42),
    'HistGradientBoosting': HistGradientBoostingClassifier(random_state=42),
    'AdaBoost': AdaBoostClassifier(n_estimators=50, random_state=42),
    'Bagging': BaggingClassifier(n_estimators=10, random_state=42),
    'XGBoost': XGBClassifier(eval_metric='mlogloss', random_state=42),
    'LogisticRegression': LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42),
    'SVM': SVC(kernel='rbf', class_weight='balanced', probability=True, random_state=42),
    'KNN': KNeighborsClassifier(n_neighbors=5),
    'GaussianNB': GaussianNB(),
    'MLP': MLPClassifier(hidden_layer_sizes=(100,), max_iter=300, random_state=42)
}

results = []
trained_models = {} 

scaler = StandardScaler()

X_train_reduced = scaler.fit_transform(X_train_reduced)
X_test_reduced = scaler.transform(X_test_reduced)

for samp_name, sampler in samplers.items():
    if sampler:
        X_res, y_res = sampler.fit_resample(X_train_reduced, y_train)
    else:
        X_res, y_res = X_train_reduced, y_train

    for model_name, model in models.items():
        model.fit(X_res, y_res)
        trained_models[(samp_name, model_name)] = model

        y_pred = model.predict(X_test_reduced)
        f1 = f1_score(y_test, y_pred, average='macro')  # or 'weighted'

        results.append({
            'Sampler': samp_name,
            'Model Name':   model_name,
            'Model': model,
            'Accuracy': accuracy_score(y_test, y_pred),
            'Macro F1': f1
        })
        print(f"Trained {model_name} with {samp_name}: macro F₁ = {f1:.4f}, accuracy = {accuracy_score(y_test, y_pred):.4f}")

# Final results table
results_df = pd.DataFrame(results).sort_values(by='Macro F1', ascending=False).reset_index(drop=True)
print("\n=== Combined Results ===")
print(results_df[['Sampler','Model Name','Macro F1','Accuracy']].to_string(index=False))

print("Accuracy based results:")
print(results_df[['Sampler','Model Name','Macro F1','Accuracy']].sort_values(by='Accuracy', ascending=False).to_string(index=False))
# Out:
# Trained DecisionTree with NoSampling: macro F₁ = 0.1849, accuracy = 0.4385
# Trained RandomForest with NoSampling: macro F₁ = 0.2237, accuracy = 0.4923
# Trained ExtraTrees with NoSampling: macro F₁ = 0.2194, accuracy = 0.4885
# Trained GradientBoosting with NoSampling: macro F₁ = 0.2496, accuracy = 0.5692
# Trained HistGradientBoosting with NoSampling: macro F₁ = 0.2725, accuracy = 0.5346
# Trained AdaBoost with NoSampling: macro F₁ = 0.1723, accuracy = 0.5538
# Trained Bagging with NoSampling: macro F₁ = 0.2212, accuracy = 0.4808
# Trained XGBoost with NoSampling: macro F₁ = 0.2492, accuracy = 0.5269
# Trained LogisticRegression with NoSampling: macro F₁ = 0.3105, accuracy = 0.4269
# Trained SVM with NoSampling: macro F₁ = 0.2280, accuracy = 0.5000
# Trained KNN with NoSampling: macro F₁ = 0.2786, accuracy = 0.5538
# Trained GaussianNB with NoSampling: macro F₁ = 0.0492, accuracy = 0.0731
# Trained MLP with NoSampling: macro F₁ = 0.2514, accuracy = 0.6192
# Trained DecisionTree with RandomOverSampler: macro F₁ = 0.1776, accuracy = 0.3923
# Trained RandomForest with RandomOverSampler: macro F₁ = 0.2116, accuracy = 0.4654
# Trained ExtraTrees with RandomOverSampler: macro F₁ = 0.2191, accuracy = 0.4808
# Trained GradientBoosting with RandomOverSampler: macro F₁ = 0.2620, accuracy = 0.4846
# Trained HistGradientBoosting with RandomOverSampler: macro F₁ = 0.2578, accuracy = 0.4808
# Trained AdaBoost with RandomOverSampler: macro F₁ = 0.1781, accuracy = 0.3462
# Trained Bagging with RandomOverSampler: macro F₁ = 0.1973, accuracy = 0.4115
# Trained XGBoost with RandomOverSampler: macro F₁ = 0.2397, accuracy = 0.4654
# Trained LogisticRegression with RandomOverSampler: macro F₁ = 0.3162, accuracy = 0.4423
# Trained SVM with RandomOverSampler: macro F₁ = 0.2325, accuracy = 0.4923
# Trained KNN with RandomOverSampler: macro F₁ = 0.2081, accuracy = 0.3962
# Trained GaussianNB with RandomOverSampler: macro F₁ = 0.0492, accuracy = 0.0731
# Trained MLP with RandomOverSampler: macro F₁ = 0.2862, accuracy = 0.4500
# Trained DecisionTree with SMOTE: macro F₁ = 0.1906, accuracy = 0.4038
# Trained RandomForest with SMOTE: macro F₁ = 0.2427, accuracy = 0.5115
# Trained ExtraTrees with SMOTE: macro F₁ = 0.3590, accuracy = 0.5115
# Trained GradientBoosting with SMOTE: macro F₁ = 0.2761, accuracy = 0.5462
# Trained HistGradientBoosting with SMOTE: macro F₁ = 0.2444, accuracy = 0.5038
# Trained AdaBoost with SMOTE: macro F₁ = 0.2669, accuracy = 0.4385
# Trained Bagging with SMOTE: macro F₁ = 0.2124, accuracy = 0.4615
# Trained XGBoost with SMOTE: macro F₁ = 0.2437, accuracy = 0.5115
# Trained LogisticRegression with SMOTE: macro F₁ = 0.3062, accuracy = 0.4038
# Trained SVM with SMOTE: macro F₁ = 0.2565, accuracy = 0.5231
# Trained KNN with SMOTE: macro F₁ = 0.3451, accuracy = 0.4269
# Trained GaussianNB with SMOTE: macro F₁ = 0.0492, accuracy = 0.0731
# Trained MLP with SMOTE: macro F₁ = 0.2967, accuracy = 0.5000
# Trained DecisionTree with BorderlineSMOTE: macro F₁ = 0.2231, accuracy = 0.4538
# Trained RandomForest with BorderlineSMOTE: macro F₁ = 0.2240, accuracy = 0.5000
# Trained ExtraTrees with BorderlineSMOTE: macro F₁ = 0.3493, accuracy = 0.5038
# Trained GradientBoosting with BorderlineSMOTE: macro F₁ = 0.2732, accuracy = 0.5308
# Trained HistGradientBoosting with BorderlineSMOTE: macro F₁ = 0.2335, accuracy = 0.4962
# Trained AdaBoost with BorderlineSMOTE: macro F₁ = 0.2294, accuracy = 0.5115
# Trained Bagging with BorderlineSMOTE: macro F₁ = 0.2514, accuracy = 0.4923
# Trained XGBoost with BorderlineSMOTE: macro F₁ = 0.2279, accuracy = 0.4808
# Trained LogisticRegression with BorderlineSMOTE: macro F₁ = 0.3186, accuracy = 0.4346
# Trained SVM with BorderlineSMOTE: macro F₁ = 0.2361, accuracy = 0.4269
# Trained KNN with BorderlineSMOTE: macro F₁ = 0.3418, accuracy = 0.4462
# Trained GaussianNB with BorderlineSMOTE: macro F₁ = 0.0884, accuracy = 0.1885
# Trained MLP with BorderlineSMOTE: macro F₁ = 0.2567, accuracy = 0.4231
# Trained DecisionTree with ADASYN: macro F₁ = 0.2033, accuracy = 0.4385
# Trained RandomForest with ADASYN: macro F₁ = 0.2369, accuracy = 0.5000
# Trained ExtraTrees with ADASYN: macro F₁ = 0.3707, accuracy = 0.5077
# Trained GradientBoosting with ADASYN: macro F₁ = 0.2748, accuracy = 0.5423
# Trained HistGradientBoosting with ADASYN: macro F₁ = 0.2428, accuracy = 0.4885
# Trained AdaBoost with ADASYN: macro F₁ = 0.1800, accuracy = 0.3654
# Trained Bagging with ADASYN: macro F₁ = 0.2196, accuracy = 0.4654
# Trained XGBoost with ADASYN: macro F₁ = 0.2490, accuracy = 0.5038
# Trained LogisticRegression with ADASYN: macro F₁ = 0.2957, accuracy = 0.4192
# Trained SVM with ADASYN: macro F₁ = 0.2370, accuracy = 0.5077
# Trained KNN with ADASYN: macro F₁ = 0.3489, accuracy = 0.4308
# Trained GaussianNB with ADASYN: macro F₁ = 0.0663, accuracy = 0.0846
# Trained MLP with ADASYN: macro F₁ = 0.2657, accuracy = 0.3769
#
# === Combined Results ===
#           Sampler           Model Name  Macro F1  Accuracy
#            ADASYN           ExtraTrees  0.370737  0.507692
#             SMOTE           ExtraTrees  0.358990  0.511538
#   BorderlineSMOTE           ExtraTrees  0.349316  0.503846
#            ADASYN                  KNN  0.348929  0.430769
#             SMOTE                  KNN  0.345065  0.426923
#   BorderlineSMOTE                  KNN  0.341786  0.446154
#   BorderlineSMOTE   LogisticRegression  0.318616  0.434615
# RandomOverSampler   LogisticRegression  0.316159  0.442308
#        NoSampling   LogisticRegression  0.310479  0.426923
#             SMOTE   LogisticRegression  0.306206  0.403846
#             SMOTE                  MLP  0.296707  0.500000
#            ADASYN   LogisticRegression  0.295739  0.419231
# RandomOverSampler                  MLP  0.286184  0.450000
#        NoSampling                  KNN  0.278565  0.553846
#             SMOTE     GradientBoosting  0.276102  0.546154
#            ADASYN     GradientBoosting  0.274759  0.542308
#   BorderlineSMOTE     GradientBoosting  0.273216  0.530769
#        NoSampling HistGradientBoosting  0.272466  0.534615
#             SMOTE             AdaBoost  0.266947  0.438462
#            ADASYN                  MLP  0.265720  0.376923
# RandomOverSampler     GradientBoosting  0.262045  0.484615
# RandomOverSampler HistGradientBoosting  0.257776  0.480769
#   BorderlineSMOTE                  MLP  0.256698  0.423077
#             SMOTE                  SVM  0.256457  0.523077
#        NoSampling                  MLP  0.251430  0.619231
#   BorderlineSMOTE              Bagging  0.251393  0.492308
#        NoSampling     GradientBoosting  0.249561  0.569231
#        NoSampling              XGBoost  0.249239  0.526923
#            ADASYN              XGBoost  0.249035  0.503846
#             SMOTE HistGradientBoosting  0.244447  0.503846
#             SMOTE              XGBoost  0.243691  0.511538
#            ADASYN HistGradientBoosting  0.242758  0.488462
#             SMOTE         RandomForest  0.242718  0.511538
# RandomOverSampler              XGBoost  0.239705  0.465385
#            ADASYN                  SVM  0.237010  0.507692
#            ADASYN         RandomForest  0.236858  0.500000
#   BorderlineSMOTE                  SVM  0.236139  0.426923
#   BorderlineSMOTE HistGradientBoosting  0.233502  0.496154
# RandomOverSampler                  SVM  0.232513  0.492308
#   BorderlineSMOTE             AdaBoost  0.229361  0.511538
#        NoSampling                  SVM  0.227995  0.500000
#   BorderlineSMOTE              XGBoost  0.227892  0.480769
#   BorderlineSMOTE         RandomForest  0.223980  0.500000
#        NoSampling         RandomForest  0.223746  0.492308
#   BorderlineSMOTE         DecisionTree  0.223091  0.453846
#        NoSampling              Bagging  0.221203  0.480769
#            ADASYN              Bagging  0.219634  0.465385
#        NoSampling           ExtraTrees  0.219438  0.488462
# RandomOverSampler           ExtraTrees  0.219059  0.480769
#             SMOTE              Bagging  0.212415  0.461538
# RandomOverSampler         RandomForest  0.211587  0.465385
# RandomOverSampler                  KNN  0.208139  0.396154
#            ADASYN         DecisionTree  0.203279  0.438462
# RandomOverSampler              Bagging  0.197303  0.411538
#             SMOTE         DecisionTree  0.190577  0.403846
#        NoSampling         DecisionTree  0.184950  0.438462
#            ADASYN             AdaBoost  0.180021  0.365385
# RandomOverSampler             AdaBoost  0.178136  0.346154
# RandomOverSampler         DecisionTree  0.177637  0.392308
#        NoSampling             AdaBoost  0.172265  0.553846
#   BorderlineSMOTE           GaussianNB  0.088434  0.188462
#            ADASYN           GaussianNB  0.066254  0.084615
#             SMOTE           GaussianNB  0.049152  0.073077
# RandomOverSampler           GaussianNB  0.049152  0.073077
#        NoSampling           GaussianNB  0.049152  0.073077
# Accuracy based results:
#           Sampler           Model Name  Macro F1  Accuracy
#        NoSampling                  MLP  0.251430  0.619231
#        NoSampling     GradientBoosting  0.249561  0.569231
#        NoSampling             AdaBoost  0.172265  0.553846
#        NoSampling                  KNN  0.278565  0.553846
#             SMOTE     GradientBoosting  0.276102  0.546154
#            ADASYN     GradientBoosting  0.274759  0.542308
#        NoSampling HistGradientBoosting  0.272466  0.534615
#   BorderlineSMOTE     GradientBoosting  0.273216  0.530769
#        NoSampling              XGBoost  0.249239  0.526923
#             SMOTE                  SVM  0.256457  0.523077
#             SMOTE         RandomForest  0.242718  0.511538
#   BorderlineSMOTE             AdaBoost  0.229361  0.511538
#             SMOTE           ExtraTrees  0.358990  0.511538
#             SMOTE              XGBoost  0.243691  0.511538
#            ADASYN                  SVM  0.237010  0.507692
#            ADASYN           ExtraTrees  0.370737  0.507692
#            ADASYN              XGBoost  0.249035  0.503846
#   BorderlineSMOTE           ExtraTrees  0.349316  0.503846
#             SMOTE HistGradientBoosting  0.244447  0.503846
#        NoSampling                  SVM  0.227995  0.500000
#   BorderlineSMOTE         RandomForest  0.223980  0.500000
#            ADASYN         RandomForest  0.236858  0.500000
#             SMOTE                  MLP  0.296707  0.500000
#   BorderlineSMOTE HistGradientBoosting  0.233502  0.496154
#        NoSampling         RandomForest  0.223746  0.492308
# RandomOverSampler                  SVM  0.232513  0.492308
#   BorderlineSMOTE              Bagging  0.251393  0.492308
#        NoSampling           ExtraTrees  0.219438  0.488462
#            ADASYN HistGradientBoosting  0.242758  0.488462
# RandomOverSampler     GradientBoosting  0.262045  0.484615
#   BorderlineSMOTE              XGBoost  0.227892  0.480769
# RandomOverSampler           ExtraTrees  0.219059  0.480769
#        NoSampling              Bagging  0.221203  0.480769
# RandomOverSampler HistGradientBoosting  0.257776  0.480769
# RandomOverSampler              XGBoost  0.239705  0.465385
# RandomOverSampler         RandomForest  0.211587  0.465385
#            ADASYN              Bagging  0.219634  0.465385
#             SMOTE              Bagging  0.212415  0.461538
#   BorderlineSMOTE         DecisionTree  0.223091  0.453846
# RandomOverSampler                  MLP  0.286184  0.450000
#   BorderlineSMOTE                  KNN  0.341786  0.446154
# RandomOverSampler   LogisticRegression  0.316159  0.442308
#            ADASYN         DecisionTree  0.203279  0.438462
#             SMOTE             AdaBoost  0.266947  0.438462
#        NoSampling         DecisionTree  0.184950  0.438462
#   BorderlineSMOTE   LogisticRegression  0.318616  0.434615
#            ADASYN                  KNN  0.348929  0.430769
#   BorderlineSMOTE                  SVM  0.236139  0.426923
#             SMOTE                  KNN  0.345065  0.426923
#        NoSampling   LogisticRegression  0.310479  0.426923
#   BorderlineSMOTE                  MLP  0.256698  0.423077
#            ADASYN   LogisticRegression  0.295739  0.419231
# RandomOverSampler              Bagging  0.197303  0.411538
#             SMOTE         DecisionTree  0.190577  0.403846
#             SMOTE   LogisticRegression  0.306206  0.403846
# RandomOverSampler                  KNN  0.208139  0.396154
# RandomOverSampler         DecisionTree  0.177637  0.392308
#            ADASYN                  MLP  0.265720  0.376923
#            ADASYN             AdaBoost  0.180021  0.365385
# RandomOverSampler             AdaBoost  0.178136  0.346154
#   BorderlineSMOTE           GaussianNB  0.088434  0.188462
#            ADASYN           GaussianNB  0.066254  0.084615
#             SMOTE           GaussianNB  0.049152  0.073077
# RandomOverSampler           GaussianNB  0.049152  0.073077
#        NoSampling           GaussianNB  0.049152  0.073077

# %%
# === Part 2: CatBoost on original X/y ===
df = pd.read_csv('/mnt/data/langchain_student_params_1300.csv').dropna()

# Binarize multi-label columns
ml_cols = ['method_of_revision','preferred_edtech_apps','knowledge_graph_nodes_covered']
for col in ml_cols:
    df[col] = df[col].apply(ast.literal_eval)
    mlb = MultiLabelBinarizer()
    dummies = mlb.fit_transform(df[col])
    df = df.join(pd.DataFrame(dummies,
                              columns=[f"{col}_{lbl}" for lbl in mlb.classes_],
                              index=df.index)).drop(columns=[col])

# Convert booleans to ints
bool_cols = df.select_dtypes(include=['bool']).columns
df[bool_cols] = df[bool_cols].astype(int)

# Split for CatBoost
X2 = df.drop(columns=['next_section'])
y2 = df['next_section'].astype('category').cat.codes
X2_train, X2_test, y2_train, y2_test = train_test_split(
    X2, y2, stratify=y2, test_size=0.2, random_state=42
)

# Train CatBoost
cat_features = X2_train.select_dtypes(include=['object','category']).columns.tolist()
cb = CatBoostClassifier(iterations=500, learning_rate=0.05, depth=6,
                        eval_metric='Accuracy', random_seed=42, verbose=False)
cb.fit(X2_train, y2_train, cat_features=cat_features, eval_set=(X2_test, y2_test))
trained_models[('NoSampling', 'CatBoost')] = cb
y2_pred = cb.predict(X2_test)
cb_acc = accuracy_score(y2_test, y2_pred)
results.append({'Sampler': 'NoSampling', 'Model': 'CatBoost', 'Accuracy': cb_acc})
print(f"Trained CatBoost: accuracy = {cb_acc:.4f}")

# Final results table
results_df = pd.DataFrame(results).sort_values(by='Accuracy', ascending=False).reset_index(drop=True)
print("\n=== Combined Results ===")
print(results_df.to_string(index=False))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 2
#       1 # === Part 2: CatBoost on original X/y ===
# ----> 2 df = pd.read_csv('/mnt/data/langchain_student_params_1300.csv').dropna()
#       4 # Binarize multi-label columns
#       5 ml_cols = ['method_of_revision','preferred_edtech_apps','knowledge_graph_nodes_covered']
#
# File c:\micromamba\envs\ml\lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\micromamba\envs\ml\lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\micromamba\envs\ml\lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\micromamba\envs\ml\lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\micromamba\envs\ml\lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/mnt/data/langchain_student_params_1300.csv'
